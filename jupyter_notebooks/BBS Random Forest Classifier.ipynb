# %%
# STANDARDS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# CUFFLINKS & PLOTLY
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_excel(r'C:\Users\krunk\OneDrive\Documents\CPSC 589\Dataset\BBS Dataset.xlsx',sheet_name='ReData')
df.head()
# Out:
#    Patient's Age  Item 1  Item 2  Item 3  Item 4  Item 5  Item 6  Item 7  \
# 0             97       1       0       1       1       1       0       0
# 1             88       2       0       1       4       3       2       2
# 2             73       3       4       3       2       2       0       2
# 3             77       2       3       1       0       4       4       2
# 4             65       3       4       1       4       4       2       4
#
#    Item 8  Item 9  Item 10  Item 11  Item 12  Item 13  Item 14  BBS Sum  \
# 0       1       1        0        0        0        1        1        8
# 1       3       4        0        1        0        4        4       30
# 2       3       1        0        1        2        4        3       30
# 3       0       1        1        0        2        3        1       24
# 4       4       2        1        2        3        3        4       41
#
#   Assessment of Risk
# 0               HIGH
# 1             MEDIUM
# 2             MEDIUM
# 3             MEDIUM
# 4                LOW

# %%
from sklearn.model_selection import train_test_split

# %%
rs = 3717

# %%
# ALL ITEMS INCLUDED

# %%
X = df.drop(['Patient\'s Age','BBS Sum','Assessment of Risk'],axis=1)
y = df['Assessment of Risk']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
y_predict = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
ex1 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex1.set_index([['Original','Original','Original','Original','Original','Original'],ex1.index],inplace=True)
ex1
# Out:
#                         LOW  MEDIUM  HIGH  precision    recall  f1-score  \
# Original LOW           39.0     0.0   0.0   1.000000  1.000000  1.000000
#          MEDIUM         0.0    36.0   1.0   1.000000  0.972973  0.986301
#          HIGH           0.0     0.0  31.0   0.968750  1.000000  0.984127
#          accuracy       NaN     NaN   NaN   0.990654  0.990654  0.990654
#          macro avg      NaN     NaN   NaN   0.989583  0.990991  0.990143
#          weighted avg   NaN     NaN   NaN   0.990946  0.990654  0.990664
#
#                           support
# Original LOW            39.000000
#          MEDIUM         37.000000
#          HIGH           31.000000
#          accuracy        0.990654
#          macro avg     107.000000
#          weighted avg  107.000000

# %%
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS)

# %%
X = df[['Item 5','Item 9','Item 10','Item 11']]
y = df['Assessment of Risk']
text = 'HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS)'

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)

y_predict = rfc.predict(X_test)

ex6 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex6.set_index([[text,text,text,text,text,text],ex6.index],inplace=True)
ex6
# Out:
#                                                                 LOW  MEDIUM  \
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS) LOW           29.0    10.0
#                                                  MEDIUM         3.0    34.0
#                                                  HIGH           0.0     2.0
#                                                  accuracy       NaN     NaN
#                                                  macro avg      NaN     NaN
#                                                  weighted avg   NaN     NaN
#
#                                                                HIGH  \
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS) LOW            0.0
#                                                  MEDIUM         0.0
#                                                  HIGH          29.0
#                                                  accuracy       NaN
#                                                  macro avg      NaN
#                                                  weighted avg   NaN
#
#                                                                precision  \
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS) LOW            0.906250
#                                                  MEDIUM         0.739130
#                                                  HIGH           1.000000
#                                                  accuracy       0.859813
#                                                  macro avg      0.881793
#                                                  weighted avg   0.875622
#
#                                                                  recall  \
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS) LOW           0.743590
#                                                  MEDIUM        0.918919
#                                                  HIGH          0.935484
#                                                  accuracy      0.859813
#                                                  macro avg     0.865998
#                                                  weighted avg  0.859813
#
#                                                                f1-score  \
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS) LOW           0.816901
#                                                  MEDIUM        0.819277
#                                                  HIGH          0.966667
#                                                  accuracy      0.859813
#                                                  macro avg     0.867615
#                                                  weighted avg  0.861113
#
#                                                                   support
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS) LOW            39.000000
#                                                  MEDIUM         37.000000
#                                                  HIGH           31.000000
#                                                  accuracy        0.859813
#                                                  macro avg     107.000000
#                                                  weighted avg  107.000000

# %%
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS)

# %%
X = df[['Item 5','Item 8','Item 9','Item 10','Item 11']]
y = df['Assessment of Risk']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)

y_predict = rfc.predict(X_test)

ex2 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex2.set_index([['HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS)','HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS)','HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS)','HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS)','HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS)','HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS)'],ex2.index],inplace=True)
ex2
# Out:
#                                                                   LOW  MEDIUM  \
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW           34.0     5.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     1.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
#
#                                                                  HIGH  \
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          30.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
#
#                                                                  precision  \
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW            1.000000
#                                                    MEDIUM         0.857143
#                                                    HIGH           0.967742
#                                                    accuracy       0.934579
#                                                    macro avg      0.941628
#                                                    weighted avg   0.941255
#
#                                                                    recall  \
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW           0.871795
#                                                    MEDIUM        0.972973
#                                                    HIGH          0.967742
#                                                    accuracy      0.934579
#                                                    macro avg     0.937503
#                                                    weighted avg  0.934579
#
#                                                                  f1-score  \
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW           0.931507
#                                                    MEDIUM        0.911392
#                                                    HIGH          0.967742
#                                                    accuracy      0.934579
#                                                    macro avg     0.936880
#                                                    weighted avg  0.935049
#
#                                                                     support
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.934579
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000

# %%
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL ITEMS)

# %%
X = df[['Item 5','Item 7','Item 8','Item 9','Item 10','Item 11']]
y = df['Assessment of Risk']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)

y_predict = rfc.predict(X_test)

ex3 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex3.set_index([['HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL ITEMS)','HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL ITEMS)','HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL ITEMS)','HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL ITEMS)','HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL ITEMS)','HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL ITEMS)'],ex3.index],inplace=True)
ex3
# Out:
#                                                                   LOW  MEDIUM  \
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW           36.0     3.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
#
#                                                                  HIGH  \
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
#
#                                                                  precision  \
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW            1.000000
#                                                    MEDIUM         0.923077
#                                                    HIGH           0.968750
#                                                    accuracy       0.962617
#                                                    macro avg      0.963942
#                                                    weighted avg   0.964347
#
#                                                                    recall  \
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW           0.923077
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.962617
#                                                    macro avg     0.965350
#                                                    weighted avg  0.962617
#
#                                                                  f1-score  \
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW           0.960000
#                                                    MEDIUM        0.947368
#                                                    HIGH          0.984127
#                                                    accuracy      0.962617
#                                                    macro avg     0.963832
#                                                    weighted avg  0.962622
#
#                                                                     support
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.962617
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000

# %%
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)

# %%
X = df[['Item 4','Item 8','Item 10','Item 11','Item 12','Item 14']]
y = df['Assessment of Risk']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)

y_predict = rfc.predict(X_test)

ex4 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex4.set_index([['DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)','DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)','DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)','DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)','DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)','DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)'],ex4.index],inplace=True)
ex4
# Out:
#                                                                  LOW  MEDIUM  \
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS) LOW           37.0     2.0
#                                                   MEDIUM         0.0    36.0
#                                                   HIGH           0.0     3.0
#                                                   accuracy       NaN     NaN
#                                                   macro avg      NaN     NaN
#                                                   weighted avg   NaN     NaN
#
#                                                                 HIGH  \
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS) LOW            0.0
#                                                   MEDIUM         1.0
#                                                   HIGH          28.0
#                                                   accuracy       NaN
#                                                   macro avg      NaN
#                                                   weighted avg   NaN
#
#                                                                 precision  \
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS) LOW            1.000000
#                                                   MEDIUM         0.878049
#                                                   HIGH           0.965517
#                                                   accuracy       0.943925
#                                                   macro avg      0.947855
#                                                   weighted avg   0.947840
#
#                                                                   recall  \
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS) LOW           0.948718
#                                                   MEDIUM        0.972973
#                                                   HIGH          0.903226
#                                                   accuracy      0.943925
#                                                   macro avg     0.941639
#                                                   weighted avg  0.943925
#
#                                                                 f1-score  \
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS) LOW           0.973684
#                                                   MEDIUM        0.923077
#                                                   HIGH          0.933333
#                                                   accuracy      0.943925
#                                                   macro avg     0.943365
#                                                   weighted avg  0.944494
#
#                                                                    support
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS) LOW            39.000000
#                                                   MEDIUM         37.000000
#                                                   HIGH           31.000000
#                                                   accuracy        0.943925
#                                                   macro avg     107.000000
#                                                   weighted avg  107.000000

# %%
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL ITEMS)

# %%
X = df[['Item 5','Item 6','Item 7','Item 8','Item 9','Item 10','Item 11']]
y = df['Assessment of Risk']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)

y_predict = rfc.predict(X_test)

ex5 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex5.set_index([['HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL ITEMS)','HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL ITEMS)','HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL ITEMS)','HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL ITEMS)','HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL ITEMS)','HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL ITEMS)'],ex5.index],inplace=True)
ex5
# Out:
#                                                                   LOW  MEDIUM  \
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW           37.0     2.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
#
#                                                                  HIGH  \
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
#
#                                                                  precision  \
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW            1.000000
#                                                    MEDIUM         0.947368
#                                                    HIGH           0.968750
#                                                    accuracy       0.971963
#                                                    macro avg      0.972039
#                                                    weighted avg   0.972747
#
#                                                                    recall  \
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW           0.948718
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.971963
#                                                    macro avg     0.973897
#                                                    weighted avg  0.971963
#
#                                                                  f1-score  \
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW           0.973684
#                                                    MEDIUM        0.960000
#                                                    HIGH          0.984127
#                                                    accuracy      0.971963
#                                                    macro avg     0.972604
#                                                    weighted avg  0.971978
#
#                                                                     support
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.971963
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000

# %%
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TOTAL ITEMS)

# %%
X = df[['Item 5','Item 6','Item 7','Item 8','Item 9','Item 10','Item 11','Item 12']]
y = df['Assessment of Risk']
text = 'HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TOTAL ITEMS)'

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)

y_predict = rfc.predict(X_test)

ex7 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex7.set_index([[text,text,text,text,text,text],ex7.index],inplace=True)
ex7
# Out:
#                                                                   LOW  MEDIUM  \
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW           36.0     3.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
#
#                                                                  HIGH  \
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
#
#                                                                  precision  \
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW            1.000000
#                                                    MEDIUM         0.923077
#                                                    HIGH           0.968750
#                                                    accuracy       0.962617
#                                                    macro avg      0.963942
#                                                    weighted avg   0.964347
#
#                                                                    recall  \
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW           0.923077
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.962617
#                                                    macro avg     0.965350
#                                                    weighted avg  0.962617
#
#                                                                  f1-score  \
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW           0.960000
#                                                    MEDIUM        0.947368
#                                                    HIGH          0.984127
#                                                    accuracy      0.962617
#                                                    macro avg     0.963832
#                                                    weighted avg  0.962622
#
#                                                                     support
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.962617
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000

# %%
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9 TOTAL ITEMS)

# %%
X = df[['Item 5','Item 6','Item 7','Item 8','Item 9','Item 10','Item 11','Item 12','Item 13']]
y = df['Assessment of Risk']
text = 'HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9 TOTAL ITEMS)'

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)

y_predict = rfc.predict(X_test)

ex8 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex8.set_index([[text,text,text,text,text,text],ex8.index],inplace=True)
ex8
# Out:
#                                                                   LOW  MEDIUM  \
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW           37.0     2.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
#
#                                                                  HIGH  \
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
#
#                                                                  precision  \
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW            1.000000
#                                                    MEDIUM         0.947368
#                                                    HIGH           0.968750
#                                                    accuracy       0.971963
#                                                    macro avg      0.972039
#                                                    weighted avg   0.972747
#
#                                                                    recall  \
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW           0.948718
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.971963
#                                                    macro avg     0.973897
#                                                    weighted avg  0.971963
#
#                                                                  f1-score  \
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW           0.973684
#                                                    MEDIUM        0.960000
#                                                    HIGH          0.984127
#                                                    accuracy      0.971963
#                                                    macro avg     0.972604
#                                                    weighted avg  0.971978
#
#                                                                     support
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.971963
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000

# %%
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4 (10 TOTAL ITEMS)

# %%
X = df[['Item 4','Item 5','Item 6','Item 7','Item 8','Item 9','Item 10','Item 11','Item 12','Item 13']]
y = df['Assessment of Risk']
text = 'HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4 (10 TOTAL ITEMS)'

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=rs)

rfc = RandomForestClassifier(n_estimators=300)
rfc.fit(X_train,y_train)

y_predict = rfc.predict(X_test)

ex9 = pd.concat([pd.DataFrame(confusion_matrix(y_test,y_predict,labels=['LOW','MEDIUM','HIGH']),index=['LOW','MEDIUM','HIGH'],columns=['LOW','MEDIUM','HIGH']),
pd.DataFrame(classification_report(y_test,y_predict,labels=['LOW','MEDIUM','HIGH'],output_dict=True)).transpose()],axis=1)
ex9.set_index([[text,text,text,text,text,text],ex9.index],inplace=True)
ex9
# Out:
#                                                                   LOW  MEDIUM  \
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW           35.0     4.0
#                                                    MEDIUM         2.0    34.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
#
#                                                                  HIGH  \
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
#
#                                                                  precision  \
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW            0.945946
#                                                    MEDIUM         0.894737
#                                                    HIGH           0.968750
#                                                    accuracy       0.934579
#                                                    macro avg      0.936478
#                                                    weighted avg   0.934845
#
#                                                                    recall  \
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW           0.897436
#                                                    MEDIUM        0.918919
#                                                    HIGH          1.000000
#                                                    accuracy      0.934579
#                                                    macro avg     0.938785
#                                                    weighted avg  0.934579
#
#                                                                  f1-score  \
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW           0.921053
#                                                    MEDIUM        0.906667
#                                                    HIGH          0.984127
#                                                    accuracy      0.934579
#                                                    macro avg     0.937282
#                                                    weighted avg  0.934352
#
#                                                                     support
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.934579
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000

# %%
finalex = pd.concat([ex1,ex6,ex2,ex3,ex4,ex5,ex7,ex8,ex9])
finalex
# Out:
#                                                                   LOW  MEDIUM  \
# Original                                           LOW           39.0     0.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS)   LOW           29.0    10.0
#                                                    MEDIUM         3.0    34.0
#                                                    HIGH           0.0     2.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW           34.0     5.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     1.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW           36.0     3.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)  LOW           37.0     2.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     3.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW           37.0     2.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW           36.0     3.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW           37.0     2.0
#                                                    MEDIUM         0.0    36.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW           35.0     4.0
#                                                    MEDIUM         2.0    34.0
#                                                    HIGH           0.0     0.0
#                                                    accuracy       NaN     NaN
#                                                    macro avg      NaN     NaN
#                                                    weighted avg   NaN     NaN
#
#                                                                  HIGH  \
# Original                                           LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS)   LOW            0.0
#                                                    MEDIUM         0.0
#                                                    HIGH          29.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          30.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)  LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          28.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW            0.0
#                                                    MEDIUM         1.0
#                                                    HIGH          31.0
#                                                    accuracy       NaN
#                                                    macro avg      NaN
#                                                    weighted avg   NaN
#
#                                                                  precision  \
# Original                                           LOW            1.000000
#                                                    MEDIUM         1.000000
#                                                    HIGH           0.968750
#                                                    accuracy       0.990654
#                                                    macro avg      0.989583
#                                                    weighted avg   0.990946
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS)   LOW            0.906250
#                                                    MEDIUM         0.739130
#                                                    HIGH           1.000000
#                                                    accuracy       0.859813
#                                                    macro avg      0.881793
#                                                    weighted avg   0.875622
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW            1.000000
#                                                    MEDIUM         0.857143
#                                                    HIGH           0.967742
#                                                    accuracy       0.934579
#                                                    macro avg      0.941628
#                                                    weighted avg   0.941255
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW            1.000000
#                                                    MEDIUM         0.923077
#                                                    HIGH           0.968750
#                                                    accuracy       0.962617
#                                                    macro avg      0.963942
#                                                    weighted avg   0.964347
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)  LOW            1.000000
#                                                    MEDIUM         0.878049
#                                                    HIGH           0.965517
#                                                    accuracy       0.943925
#                                                    macro avg      0.947855
#                                                    weighted avg   0.947840
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW            1.000000
#                                                    MEDIUM         0.947368
#                                                    HIGH           0.968750
#                                                    accuracy       0.971963
#                                                    macro avg      0.972039
#                                                    weighted avg   0.972747
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW            1.000000
#                                                    MEDIUM         0.923077
#                                                    HIGH           0.968750
#                                                    accuracy       0.962617
#                                                    macro avg      0.963942
#                                                    weighted avg   0.964347
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW            1.000000
#                                                    MEDIUM         0.947368
#                                                    HIGH           0.968750
#                                                    accuracy       0.971963
#                                                    macro avg      0.972039
#                                                    weighted avg   0.972747
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW            0.945946
#                                                    MEDIUM         0.894737
#                                                    HIGH           0.968750
#                                                    accuracy       0.934579
#                                                    macro avg      0.936478
#                                                    weighted avg   0.934845
#
#                                                                    recall  \
# Original                                           LOW           1.000000
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.990654
#                                                    macro avg     0.990991
#                                                    weighted avg  0.990654
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS)   LOW           0.743590
#                                                    MEDIUM        0.918919
#                                                    HIGH          0.935484
#                                                    accuracy      0.859813
#                                                    macro avg     0.865998
#                                                    weighted avg  0.859813
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW           0.871795
#                                                    MEDIUM        0.972973
#                                                    HIGH          0.967742
#                                                    accuracy      0.934579
#                                                    macro avg     0.937503
#                                                    weighted avg  0.934579
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW           0.923077
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.962617
#                                                    macro avg     0.965350
#                                                    weighted avg  0.962617
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)  LOW           0.948718
#                                                    MEDIUM        0.972973
#                                                    HIGH          0.903226
#                                                    accuracy      0.943925
#                                                    macro avg     0.941639
#                                                    weighted avg  0.943925
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW           0.948718
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.971963
#                                                    macro avg     0.973897
#                                                    weighted avg  0.971963
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW           0.923077
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.962617
#                                                    macro avg     0.965350
#                                                    weighted avg  0.962617
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW           0.948718
#                                                    MEDIUM        0.972973
#                                                    HIGH          1.000000
#                                                    accuracy      0.971963
#                                                    macro avg     0.973897
#                                                    weighted avg  0.971963
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW           0.897436
#                                                    MEDIUM        0.918919
#                                                    HIGH          1.000000
#                                                    accuracy      0.934579
#                                                    macro avg     0.938785
#                                                    weighted avg  0.934579
#
#                                                                  f1-score  \
# Original                                           LOW           1.000000
#                                                    MEDIUM        0.986301
#                                                    HIGH          0.984127
#                                                    accuracy      0.990654
#                                                    macro avg     0.990143
#                                                    weighted avg  0.990664
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS)   LOW           0.816901
#                                                    MEDIUM        0.819277
#                                                    HIGH          0.966667
#                                                    accuracy      0.859813
#                                                    macro avg     0.867615
#                                                    weighted avg  0.861113
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW           0.931507
#                                                    MEDIUM        0.911392
#                                                    HIGH          0.967742
#                                                    accuracy      0.934579
#                                                    macro avg     0.936880
#                                                    weighted avg  0.935049
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW           0.960000
#                                                    MEDIUM        0.947368
#                                                    HIGH          0.984127
#                                                    accuracy      0.962617
#                                                    macro avg     0.963832
#                                                    weighted avg  0.962622
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)  LOW           0.973684
#                                                    MEDIUM        0.923077
#                                                    HIGH          0.933333
#                                                    accuracy      0.943925
#                                                    macro avg     0.943365
#                                                    weighted avg  0.944494
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW           0.973684
#                                                    MEDIUM        0.960000
#                                                    HIGH          0.984127
#                                                    accuracy      0.971963
#                                                    macro avg     0.972604
#                                                    weighted avg  0.971978
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW           0.960000
#                                                    MEDIUM        0.947368
#                                                    HIGH          0.984127
#                                                    accuracy      0.962617
#                                                    macro avg     0.963832
#                                                    weighted avg  0.962622
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW           0.973684
#                                                    MEDIUM        0.960000
#                                                    HIGH          0.984127
#                                                    accuracy      0.971963
#                                                    macro avg     0.972604
#                                                    weighted avg  0.971978
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW           0.921053
#                                                    MEDIUM        0.906667
#                                                    HIGH          0.984127
#                                                    accuracy      0.934579
#                                                    macro avg     0.937282
#                                                    weighted avg  0.934352
#
#                                                                     support
# Original                                           LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.990654
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000
# HIGH CORR TOP 4 PICKED 9,11,10,5 (4 TOTAL ITEMS)   LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.859813
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000
# HIGH CORR TOP 5 PICKED 9,11,10,5,8 (5 TOTAL ITEMS) LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.934579
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000
# HIGH CORR TOP 6 PICKED 9,11,10,5,8,7 (6 TOTAL I... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.962617
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000
# DS PRACTICAL PICK 14,12,11,10,8,4 (6 TOTAL ITEMS)  LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.943925
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000
# HIGH CORR TOP 7 PICKED 9,11,10,5,8,7,6 (7 TOTAL... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.971963
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000
# HIGH CORR TOP 8 PICKED 9,11,10,5,8,7,6,12 (8 TO... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.962617
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000
# HIGH CORR TOP 9 PICKED 9,11,10,5,8,7,6,12,13 (9... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.971963
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000
# HIGH CORR TOP 10 PICKED 9,11,10,5,8,7,6,12,13,4... LOW            39.000000
#                                                    MEDIUM         37.000000
#                                                    HIGH           31.000000
#                                                    accuracy        0.934579
#                                                    macro avg     107.000000
#                                                    weighted avg  107.000000

# %%
finalex.to_excel(r'C:\Users\krunk\OneDrive\Documents\CPSC 597\Project Data\BBS Machine Learning Data Collection (Random Forest Classifier).xlsx',sheet_name='Random Forest Classifier')
